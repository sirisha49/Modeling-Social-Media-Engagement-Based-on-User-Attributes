# %% [markdown]
# *Developed by (Name: Sai Sirisha Nidraghatta Karanam)*

# %% [markdown]
# ## 1. Introduction
# Introduction/Background
# The dataset used for this analysis focuses on social media engagement, capturing key variables such as hours spent on social media, user interests, age, and platform preferences. The data provides valuable insights into user behavior across different social media platforms and interest groups. It includes both categorical variables like user interests (e.g., sports, education, entertainment) and platforms (e.g., Instagram, Facebook) as well as numerical variables such as age and hours spent. This dataset is designed to help understand patterns of social media usage and identify factors that drive user engagement.
#
# The data source for this analysis could be hypothetical or from a public platform like Kaggle, where anonymized user behavior data is collected for academic and research purposes.
#
# ## Reason for Interest in the Dataset
# The dataset provides an in-depth look at social media usage, allowing us to explore how different users engage with various platforms based on their interests, age, and time spent. In a world where social media plays a pivotal role in daily interactions, understanding what drives user engagement is crucial for developing content strategies, improving user experiences, and optimizing platform features. This dataset is particularly interesting because it captures both demographic and behavioral data, making it possible to study how different factors influence social media usage patterns. By analyzing this data, we aim to uncover key insights about platform popularity, user engagement, and interest-based behavior.
#
# ## 2. Research Objectives and Goals
# The primary objective of this research is to explore and understand user engagement on social media platforms. Specifically, the analysis aims to achieve the following goals:
#
# Identify the average time spent on social media platforms and analyze the factors (such as age and gender) that influence this behavior.
# Determine the most popular platform in terms of user engagement and time spent, highlighting which platforms attract the most active users.
# Explore the distribution of user interests and how different interests impact the time users spend on social media. Additionally, the research seeks to identify whether demographic factors like age affect user engagement based on interests.
#
# ## EDA Hypotheses
# ### Questions:
#
# 1. What is the average time spent on social media across all users?
#
# Reason for Interest: Understanding the average time users spend on social media provides a baseline for engagement and helps identify patterns of usage. It also allows us to see if there are any significant differences based on factors like age or gender. We are particularly interested in knowing if certain demographics spend more time on social media than others and what the overall user engagement looks like.
#
# 2. What is the most popular platform in the dataset?
#
# Reason for Interest: Social media platforms vary widely in terms of their user engagement, and knowing which platform attracts the most time from users is crucial for understanding platform success. We want to see if platforms like Instagram are more engaging than others (e.g., Facebook, Twitter) and how users distribute their time across these platforms.
#
# 3. What is the distribution of interests among users?
#
# Reason for Interest: Users have different interests, and those interests often drive the type of content they engage with on social media. By understanding the distribution of user interests and how it impacts time spent on social media, we can determine which interest groups are most engaged. This information is valuable for content creators and marketers who need to target specific user segments effectively.

# %% [markdown]
# ## 2. Data Analysis
#
# ### 2-1. Importing the libraries necessary for your EDA

# %%
# Import your data easy to read
import pandas as pd

# Load the dataset (update the path to your dataset)
file_path = 'Social Media Analytics.xls'  # Replace with the correct file path
data = pd.read_excel(file_path)

# Display the first 5 rows of the dataset for easy reading
pd.set_option('display.max_columns', None)  # This will show all columns without truncation
pd.set_option('display.expand_frame_repr', False)  # Prevent line wrapping
print("Displaying first 5 rows of the dataset:")
data.head()
# Out:
# Displaying first 5 rows of the dataset:
#    age      gender  time_spent   platform  interests        location demographics         profession  income
# 0   56        male           3  Instagram     Sports  United Kingdom        Urban  Software Engineer   19774
# 1   46      female           2   Facebook     Travel  United Kingdom        Urban            Student   10564
# 2   32        male           8  Instagram     Sports       Australia    Sub_Urban   Marketer Manager   13258
# 3   60  non-binary           5  Instagram     Travel  United Kingdom        Urban            Student   12500
# 4   25        male           1  Instagram  Lifestlye       Australia        Urban  Software Engineer   14566

# %% [markdown]
# ### 2-2. Import libraries for EDA

# %%
# Import libraries for EDA 
import pandas as pd  # For data manipulation and analysis
import numpy as np  # For numerical computations
import matplotlib.pyplot as plt  # For plotting graphs
import seaborn as sns  # For statistical data visualization

# %% [markdown]
# ### 2-3. Review Data

# %%
# 1. Check data dimension by using .shape
data_shape = data.shape

print(f"The dataset has {data_shape[0]} rows and {data_shape[1]} columns.")
# Out:
# The dataset has 1000 rows and 9 columns.

# %%
# 2. Check types of data by .info() ; .dtype
# 1. Check data types and non-null values using .info()
print("Dataset Information:")
data.info()

# 2. Check data types of each column using .dtypes
print("\nData Types of Each Column:")
print(data.dtypes)
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           1000 non-null   int64
#  1   gender        1000 non-null   object
#  2   time_spent    1000 non-null   int64
#  3   platform      1000 non-null   object
#  4   interests     1000 non-null   object
#  5   location      1000 non-null   object
#  6   demographics  1000 non-null   object
#  7   profession    1000 non-null   object
#  8   income        1000 non-null   int64
# dtypes: int64(3), object(6)
# memory usage: 70.4+ KB
#
# Data Types of Each Column:
# age              int64
# gender          object
# time_spent       int64
# platform        object
# interests       object
# location        object
# demographics    object
# profession      object
# income           int64
# dtype: object

# %%
# 3. For quantitative variable, generate a table for the count, mean, standard deviation, minimum and maximum values and the quantities of the data 
# Generate summary statistics for quantitative variables
quantitative_summary = data.describe()

print("Summary statistics for quantitative variables:")
print(quantitative_summary)
# Out:
# Summary statistics for quantitative variables:
#                age   time_spent        income
# count  1000.000000  1000.000000   1000.000000
# mean     40.986000     5.029000  15014.823000
# std      13.497852     2.537834   2958.628221
# min      18.000000     1.000000  10012.000000
# 25%      29.000000     3.000000  12402.250000
# 50%      42.000000     5.000000  14904.500000
# 75%      52.000000     7.000000  17674.250000
# max      64.000000     9.000000  19980.000000

# %% [markdown]
# ### 2-4. Generate Sub-dataset

# %%
# 1. Make sub-dataset(s) from your original dataset for your research objective, goals by dropping unnecessary variables 
# Define the columns to keep for question 1
columns_q1 = ['age', 'gender', 'time_spent']

# Create sub-dataset for question 1
sub_dataset_q1 = data[columns_q1]

# Display the first 5 rows of the sub-dataset
print("Sub-dataset for Question 1:")
sub_dataset_q1.head()

# Calculate the average time spent on social media
average_time_spent = sub_dataset_q1['time_spent'].mean()
print(f"The average time spent on social media is {average_time_spent} hours.")
# Out:
# Sub-dataset for Question 1:
# The average time spent on social media is 5.029 hours.

# %%
# Define the columns to keep for question 2
columns_q2 = ['platform', 'time_spent']

# Create sub-dataset for question 2
sub_dataset_q2 = data[columns_q2]

# Display the first 5 rows of the sub-dataset
print("Sub-dataset for Question 2:")
sub_dataset_q2.head()

# Find the most popular platform
most_popular_platform = sub_dataset_q2['platform'].value_counts().idxmax()
print(f"The most popular social media platform is {most_popular_platform}.")
# Out:
# Sub-dataset for Question 2:
# The most popular social media platform is Instagram.

# %%
# Define the columns to keep for question 3
columns_q3 = ['interests']

# Create sub-dataset for question 3
sub_dataset_q3 = data[columns_q3]

# Display the first 5 rows of the sub-dataset
print("Sub-dataset for Question 3:")
sub_dataset_q3.head()

# Display the distribution of interests
interest_distribution = sub_dataset_q3['interests'].value_counts()
print("Distribution of interests among users:")
print(interest_distribution)
# Out:
# Sub-dataset for Question 3:
# Distribution of interests among users:
# interests
# Lifestlye    341
# Sports       331
# Travel       328
# Name: count, dtype: int64

# %%
# 2. try to change variable names

# Rename variables in the sub-dataset for Question 1
sub_dataset_q1_renamed = sub_dataset_q1.rename(columns={
    'age': 'user_age',
    'gender': 'user_gender',
    'time_spent': 'hours_spent'
})

# %%
# Rename variables in the sub-dataset for Question 2
sub_dataset_q2_renamed = sub_dataset_q2.rename(columns={
    'platform': 'social_media_platform',
    'time_spent': 'hours_spent'
})

# %%
# Rename variables in the sub-dataset for Question 3
sub_dataset_q3_renamed = sub_dataset_q3.rename(columns={
    'interests': 'user_interests'
})

# %%
# 3. check if there are missing values
# Check for missing values in the original dataset
missing_values = data.isnull().sum()
print("Missing values in the original dataset:")
print(missing_values)
# Out:
# Missing values in the original dataset:
# age             0
# gender          0
# time_spent      0
# platform        0
# interests       0
# location        0
# demographics    0
# profession      0
# income          0
# dtype: int64

# %%
# Check for missing values in sub-dataset for Question 1
missing_values_q1 = sub_dataset_q1_renamed.isnull().sum()
print("\nMissing values in sub-dataset for Question 1:")
print(missing_values_q1)
# Out:
# Missing values in sub-dataset for Question 1:
# user_age       0
# user_gender    0
# hours_spent    0
# dtype: int64

# %%
# Check for missing values in sub-dataset for Question 2
missing_values_q2 = sub_dataset_q2_renamed.isnull().sum()
print("\nMissing values in sub-dataset for Question 2:")
print(missing_values_q2)
# Out:
# Missing values in sub-dataset for Question 2:
# social_media_platform    0
# hours_spent              0
# dtype: int64

# %%
# Check for missing values in sub-dataset for Question 3
missing_values_q3 = sub_dataset_q3_renamed.isnull().sum()
print("\nMissing values in sub-dataset for Question 3:")
print(missing_values_q3)
# Out:
# Missing values in sub-dataset for Question 3:
# user_interests    0
# dtype: int64

# %%
# 4. Check if there are duplicated values
# Check for duplicated rows in the original dataset
duplicates_in_original = data.duplicated().sum()
print(f"Number of duplicated rows in the original dataset: {duplicates_in_original}")
# Out:
# Number of duplicated rows in the original dataset: 0

# %%
# Check for duplicated rows in the sub-dataset for Question 1
duplicates_in_q1 = sub_dataset_q1_renamed.duplicated().sum()
print(f"Number of duplicated rows in sub-dataset for Question 1: {duplicates_in_q1}")
# Out:
# Number of duplicated rows in sub-dataset for Question 1: 304

# %%
# Check for duplicated rows in the sub-dataset for Question 2
duplicates_in_q2 = sub_dataset_q2_renamed.duplicated().sum()
print(f"Number of duplicated rows in sub-dataset for Question 2: {duplicates_in_q2}")
# Out:
# Number of duplicated rows in sub-dataset for Question 2: 973

# %%
# Check for duplicated rows in the sub-dataset for Question 3
duplicates_in_q3 = sub_dataset_q3_renamed.duplicated().sum()
print(f"Number of duplicated rows in sub-dataset for Question 3: {duplicates_in_q3}")
# Out:
# Number of duplicated rows in sub-dataset for Question 3: 997

# %% [markdown]
# ### 2-5. Checking Outliers

# %%
# check if quantitative variables have outliers.
# Define a function to detect outliers using IQR
def detect_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return outliers

# List of quantitative variables
quantitative_vars = ['age', 'time_spent', 'income']  # Modify based on your dataset

# Check for outliers in each quantitative variable
for var in quantitative_vars:
    outliers = detect_outliers_iqr(data, var)
    print(f"\nOutliers in '{var}':")
    print(outliers if not outliers.empty else "No outliers found")
# Out:
# Outliers in 'age':
# No outliers found
#
# Outliers in 'time_spent':
# No outliers found
#
# Outliers in 'income':
# No outliers found

# %% [markdown]
# ### 2-6. Generating Plot(s)

# %%
# generate plots to support your objective and goals
# Question 1 
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram of time spent on social media
plt.figure(figsize=(8,6))
sns.histplot(sub_dataset_q1_renamed['hours_spent'], bins=10, kde=True, color='blue')
plt.title('Distribution of Time Spent on Social Media', fontsize=16)
plt.xlabel('Hours Spent', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# Boxplot of time spent to detect outliers
plt.figure(figsize=(8,6))
sns.boxplot(x=sub_dataset_q1_renamed['hours_spent'], color='orange')
plt.title('Boxplot of Time Spent on Social Media', fontsize=16)
plt.xlabel('Hours Spent', fontsize=12)
plt.show()

# %%
# Bar plot of social media platforms
# Question 2 
plt.figure(figsize=(8,6))
sns.countplot(x='social_media_platform', data=sub_dataset_q2_renamed, palette='viridis')
plt.title('Most Popular Social Media Platforms', fontsize=16)
plt.xlabel('Platform', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Sirisha\AppData\Local\Temp\ipykernel_28972\666997675.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='social_media_platform', data=sub_dataset_q2_renamed, palette='viridis')

# %%
# Donut chart for the distribution of user interests
#question 3 
plt.figure(figsize=(8,8))
user_interests_counts = sub_dataset_q3_renamed['user_interests'].value_counts()
plt.pie(user_interests_counts, labels=user_interests_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('Set2'), wedgeprops=dict(width=0.3))
plt.gca().add_artist(plt.Circle((0,0), 0.70, color='white'))  # This creates the donut hole
plt.title('Distribution of User Interests', fontsize=16)
plt.show()

# %% [markdown]
# ## 3. EDA

# %% [markdown]
# Question 1 : What is the average time spent on social media across all users?

# %%
# perform your EDA
# Import necessary libraries
from scipy import stats

# Calculate summary statistics for 'hours_spent'
mean_time_spent = sub_dataset_q1_renamed['hours_spent'].mean()
median_time_spent = sub_dataset_q1_renamed['hours_spent'].median()
mode_time_spent = sub_dataset_q1_renamed['hours_spent'].mode()[0]
std_time_spent = sub_dataset_q1_renamed['hours_spent'].std()

# Print the summary statistics
print(f"Mean time spent on social media: {mean_time_spent} hours")
print(f"Median time spent on social media: {median_time_spent} hours")
print(f"Mode time spent on social media: {mode_time_spent} hours")
print(f"Standard deviation of time spent: {std_time_spent} hours")
# Out:
# Mean time spent on social media: 5.029 hours
# Median time spent on social media: 5.0 hours
# Mode time spent on social media: 5 hours
# Standard deviation of time spent: 2.537833643011226 hours

# %%
# Enhanced histogram for time spent on social media
plt.figure(figsize=(8,4))
sns.histplot(sub_dataset_q1_renamed['hours_spent'], bins=15, kde=False, color='#1f77b4', edgecolor='black')

# Add labels, title, and grid
plt.title('Distribution of Time Spent on Social Media', fontsize=18, fontweight='bold')
plt.xlabel('Hours Spent', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Add gridlines for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Display mean on the histogram
mean_time_spent = sub_dataset_q1_renamed['hours_spent'].mean()
plt.axvline(mean_time_spent, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_time_spent:.2f} hours')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
# Plot box plot to visualize the distribution of 'hours_spent' and detect outliers
plt.figure(figsize=(6,4))
sns.boxplot(x=sub_dataset_q1_renamed['hours_spent'], color='orange')
plt.title('Box Plot of Time Spent on Social Media', fontsize=16)
plt.xlabel('Hours Spent', fontsize=12)
plt.show()

# %%
# Enhanced density plot for time spent on social media
plt.figure(figsize=(8,4))

# Plot density plot with shading, a custom color, and linewidth adjustments
sns.kdeplot(sub_dataset_q1_renamed['hours_spent'], shade=True, color='#2ca02c', linewidth=2, alpha=0.5)

# Add labels and title
plt.title('Density Plot of Time Spent on Social Media', fontsize=18, fontweight='bold')
plt.xlabel('Hours Spent', fontsize=14)
plt.ylabel('Density', fontsize=14)

# Add gridlines for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Display mean on the density plot
mean_time_spent = sub_dataset_q1_renamed['hours_spent'].mean()
plt.axvline(mean_time_spent, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_time_spent:.2f} hours')

# Add legend
plt.legend()

# Show the plot
plt.show()
# Out:
# C:\Users\Sirisha\AppData\Local\Temp\ipykernel_28972\1719792742.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(sub_dataset_q1_renamed['hours_spent'], shade=True, color='#2ca02c', linewidth=2, alpha=0.5)

# %%
#Bivariate Analysis 

from sklearn.cluster import KMeans

# Preparing the data for clustering: we'll use 'user_age' and 'hours_spent'
data_for_clustering = sub_dataset_q1_renamed[['user_age', 'hours_spent']]

# Applying KMeans clustering with 3 clusters (you can change the number of clusters if needed)
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(data_for_clustering)

# Add cluster labels to the dataset
sub_dataset_q1_renamed['cluster'] = clusters

# Plot scatter plot with clusters
plt.figure(figsize=(5,4))
sns.scatterplot(x='user_age', y='hours_spent', data=sub_dataset_q1_renamed, hue='cluster', palette='Set1', s=30, alpha=0.7)
plt.title('Scatter Plot of Age vs Time Spent on Social Media (Clustered)', fontsize=10)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Hours Spent on Social Media', fontsize=12)
plt.grid(True)
plt.legend(title='Cluster')
plt.show()

# %%
# Pair plot to visualize relationships between 'user_age', 'hours_spent', and 'user_gender'
sns.pairplot(sub_dataset_q1_renamed, hue='user_gender', vars=['user_age', 'hours_spent'], palette='Set1')
plt.suptitle('Pair Plot: Age, Gender, and Time Spent on Social Media', fontsize=10)
plt.show()

# %%
Multivarient Analysis

# Drop non-numeric columns from the dataset
numeric_data = sub_dataset_q1_renamed.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation matrix for numeric variables only
corr_matrix_multivariate = numeric_data.corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(5,4))
sns.heatmap(corr_matrix_multivariate, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap: Numeric Variables', fontsize=16)
plt.show()

# Pair plot to visualize pairwise relationships between age, hours_spent, and gender
sns.pairplot(sub_dataset_q1_renamed, hue='user_gender', diag_kind='kde', palette='Set2')
plt.suptitle('Par Plot of Age, Time Spent, and Gender', y=1.02, fontsize=16)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Standardize the data (mean=0, variance=1)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(sub_dataset_q1_renamed[['user_age', 'hours_spent', 'gender_numeric']])

# Apply PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(X_scaled)

# Add PCA results to the dataset
sub_dataset_q1_renamed['pca_one'] = pca_result[:, 0]
sub_dataset_q1_renamed['pca_two'] = pca_result[:, 1]

# Plot variance explained by each principal component
explained_variance = pca.explained_variance_ratio_
plt.figure(figsize=(5,3))
plt.bar(['PC1', 'PC2'], explained_variance * 100, color='lightgreen')
plt.title('Variance Explained by Principal Components', fontsize=13)
plt.ylabel('Percentage of Variance Explained', fontsize=12)
plt.show()

# Plot PCA results
plt.figure(figsize=(8,6))
sns.scatterplot(x='pca_one', y='pca_two', hue='user_gender', data=sub_dataset_q1_renamed, palette='Set1', s=100, alpha=0.7)
plt.title('PCA Plot of Age, Hours Spent, and Gender', fontsize=16)
plt.xlabel('Principal Component 1', fontsize=12)
plt.ylabel('Principal Component 2', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# Question 2:   What is the most popular platform in the dataset?

# %%
#1 Univarient 
# Group by platform and calculate summary statistics for time spent on each platform
summary_stats = sub_dataset_q2_renamed.groupby('social_media_platform')['hours_spent'].describe()

print("Summary statistics for hours spent on each platform:")
print(summary_stats)
# Out:
# Summary statistics for hours spent on each platform:
#                        count      mean       std  min  25%  50%  75%  max
# social_media_platform
# Facebook               307.0  5.055375  2.502325  1.0  3.0  5.0  7.0  9.0
# Instagram              363.0  5.151515  2.609305  1.0  3.0  5.0  7.0  9.0
# YouTube                330.0  4.869697  2.489734  1.0  3.0  5.0  7.0  9.0

# %%
# Plot histograms of time spent for each platform
plt.figure(figsize=(8,4))
sns.histplot(data=sub_dataset_q2_renamed, x='hours_spent', hue='social_media_platform', multiple='stack', palette='Set2')
plt.title('Histogram of Time Spent on Social Media Platforms', fontsize=16)
plt.xlabel('Hours Spent', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.legend(title='Platform')
plt.show()
# Boxplot of time spent across different platforms
plt.figure(figsize=(8,4))
sns.boxplot(x='social_media_platform', y='hours_spent', data=sub_dataset_q2_renamed, palette='Set1')
plt.title('Box Plot of Time Spent on Social Media Platforms', fontsize=16)
plt.xlabel('Platform', fontsize=12)
plt.ylabel('Hours Spent', fontsize=12)
plt.show()
# Density plot for time spent across different platforms
plt.figure(figsize=(8,6))
sns.kdeplot(data=sub_dataset_q2_renamed, x='hours_spent', hue='social_media_platform', fill=True, palette='Set3')
plt.title('Density Plot of Time Spent on Social Media Platforms', fontsize=16)
plt.xlabel('Hours Spent', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\Sirisha\AppData\Local\Temp\ipykernel_28972\1272954100.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='social_media_platform', y='hours_spent', data=sub_dataset_q2_renamed, palette='Set1')

# %%
#bivariate 
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# Preparing data for clustering (only 'hours_spent' for clustering as platform is categorical)
X = sub_dataset_q2_renamed[['hours_spent']]

# Applying KMeans clustering with 3 clusters (you can change the number of clusters if needed)
kmeans = KMeans(n_clusters=3, random_state=42)
sub_dataset_q2_renamed['cluster'] = kmeans.fit_predict(X)

# Plot scatter plot with clusters
plt.figure(figsize=(6,4))
sns.scatterplot(x='social_media_platform', y='hours_spent', hue='cluster', data=sub_dataset_q2_renamed, palette='Set1', s=100, alpha=0.7)
plt.title('Scatter Plot of Time Spent on Social Media Platforms with Clusters', fontsize=16)
plt.xlabel('Social Media Platform', fontsize=12)
plt.ylabel('Hours Spent on Social Media', fontsize=12)
plt.legend(title='Cluster')
plt.grid(True)
plt.show()

# %%
# Use the available numerical variables: 'hours_spent', 'age', and 'income'
correlation_matrix = sub_dataset_q2_renamed[['hours_spent', 'age', 'income']].corr()

# Plot the correlation matrix
plt.figure(figsize=(6,4))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Hours Spent, Age, and Income', fontsize=16)
plt.show()

# %%
# Pair plot of hours_spent, age, and platform
sns.pairplot(sub_dataset_q2_renamed, vars=['hours_spent', 'age', 'income'], hue='social_media_platform', palette='Set2')
plt.suptitle('Pair Plot of Time Spent, Age, and Income with Platform as Hue', y=1.02, fontsize=16)
plt.show()

# %%
# Multivariate

# %%
# Compute the correlation matrix
correlation_matrix = sub_dataset_q2_renamed[['hours_spent', 'age', 'income']].corr()

# Plot the heatmap
plt.figure(figsize=(6,4))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Hours Spent, Age, and Income', fontsize=16)
plt.show()

# %%
# Scatter plot of age vs hours spent, colored by platform
plt.figure(figsize=(8,6))
sns.scatterplot(x='age', y='hours_spent', hue='social_media_platform', data=sub_dataset_q2_renamed, palette='Set2', s=100, alpha=0.7)
plt.title('Scatter Plot of Age vs Hours Spent on Social Media', fontsize=16)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Hours Spent', fontsize=12)
plt.grid(True)
plt.show()

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# Add dummy numerical variables (like age and income) for demonstration
np.random.seed(42)
sub_dataset_q2_renamed['age'] = np.random.randint(18, 65, size=sub_dataset_q2_renamed.shape[0])
sub_dataset_q2_renamed['income'] = np.random.randint(20000, 100000, size=sub_dataset_q2_renamed.shape[0])

# Standardize the data before applying PCA
scaler = StandardScaler()
X_scaled = scaler.fit_transform(sub_dataset_q2_renamed[['hours_spent', 'age', 'income']])

# Apply PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(X_scaled)

# Add PCA results to the dataset
sub_dataset_q2_renamed['pca_one'] = pca_result[:, 0]
sub_dataset_q2_renamed['pca_two'] = pca_result[:, 1]

# Plot the PCA result
plt.figure(figsize=(8,6))
sns.scatterplot(x='pca_one', y='pca_two', hue='social_media_platform', data=sub_dataset_q2_renamed, palette='Set1', s=100, alpha=0.7)
plt.title('PCA Plot of Time Spent, Age, and Income by Platforms', fontsize=16)
plt.xlabel('Principal Component 1', fontsize=12)
plt.ylabel('Principal Component 2', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# Question 3
# What is the distribution of interests among users?

# %%
# Count the frequency of each unique interest
interest_counts = sub_dataset_q3_renamed['user_interests'].value_counts()

# Display the counts and percentages
interest_percentages = interest_counts / interest_counts.sum() * 100

print("Frequency of each interest:")
print(interest_counts)

print("\nPercentage distribution of each interest:")
print(interest_percentages)
# Out:
# Frequency of each interest:
# user_interests
# Lifestlye    341
# Sports       331
# Travel       328
# Name: count, dtype: int64
#
# Percentage distribution of each interest:
# user_interests
# Lifestlye    34.1
# Sports       33.1
# Travel       32.8
# Name: count, dtype: float64

# %%
# Bar plot for distribution of interests
plt.figure(figsize=(8,4))
sns.barplot(x=interest_counts.index, y=interest_counts.values, palette='Set2')
plt.title('Distribution of Interests Among Users', fontsize=16)
plt.xlabel('Interests', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Sirisha\AppData\Local\Temp\ipykernel_28972\313119014.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=interest_counts.index, y=interest_counts.values, palette='Set2')

# %%
# Assuming you have a dataset with 'hours_spent' for each user
sub_dataset_q3_renamed['hours_spent'] = [np.random.randint(1, 10) for _ in range(len(sub_dataset_q3_renamed))]  # Dummy data for demonstration

# Now we can create the box plot
plt.figure(figsize=(10,6))
sns.boxplot(x='user_interests', y='hours_spent', data=sub_dataset_q3_renamed, palette='Set2')
plt.title('Box Plot of Time Spent on Social Media by User Interests', fontsize=16)
plt.xlabel('User Interests', fontsize=12)
plt.ylabel('Hours Spent on Social Media', fontsize=12)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Sirisha\AppData\Local\Temp\ipykernel_28972\542616505.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='user_interests', y='hours_spent', data=sub_dataset_q3_renamed, palette='Set2')

# %%
# Density plot (KDE) for time spent across different user interests
plt.figure(figsize=(8,4))
sns.kdeplot(data=sub_dataset_q3_renamed, x='hours_spent', hue='user_interests', fill=True, palette='Set3')
plt.title('Density Plot of Time Spent on Social Media by User Interests', fontsize=16)
plt.xlabel('Hours Spent on Social Media', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.show()

# %%
Bivariate Analysis

# %%
# Enhanced scatter plot with hue and transparency
plt.figure(figsize=(8,4))

# Scatter plot with hue for interests, adjusting marker size and transparency
sns.scatterplot(x='user_interests', y='hours_spent', data=sub_dataset_q3_renamed, hue='user_interests', 
                palette='Set1', s=100, alpha=0.6, marker='o')

plt.title('Enhanced Scatter Plot of User Interests vs Hours Spent', fontsize=16)
plt.xlabel('User Interests', fontsize=12)
plt.ylabel('Hours Spent', fontsize=12)
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Create another dummy numerical variable for demonstration
sub_dataset_q3_renamed['age'] = np.random.randint(18, 60, size=len(sub_dataset_q3_renamed))

# Generate correlation matrix
correlation_matrix = sub_dataset_q3_renamed[['hours_spent', 'age']].corr()

# Plot heatmap of the correlation matrix
plt.figure(figsize=(6,4))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Hours Spent and Age', fontsize=16)
plt.show()

# Pair plot to visualize pairwise relationships between hours_spent and age
sns.pairplot(sub_dataset_q3_renamed, hue='user_interests', diag_kind='kde', palette='Set2')
plt.suptitle('Pair Plot of Hours Spent and Age by User Interests', y=1.02, fontsize=16)
plt.show()

# %% [markdown]
# Multivariate  Analysis

# %%
# Dummy data for age and hours_spent
np.random.seed(42)
sub_dataset_q3_renamed['hours_spent'] = np.random.randint(1, 10, size=len(sub_dataset_q3_renamed))
sub_dataset_q3_renamed['age'] = np.random.randint(18, 65, size=len(sub_dataset_q3_renamed))

# Generate correlation matrix
correlation_matrix = sub_dataset_q3_renamed[['hours_spent', 'age']].corr()

# Plot heatmap of the correlation matrix
plt.figure(figsize=(6,4))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap for Hours Spent and Age', fontsize=16)
plt.show()


# Assuming you already have user_interests, and we create dummy data for hours_spent and age
np.random.seed(42)
sub_dataset_q3_renamed['hours_spent'] = np.random.randint(1, 10, size=len(sub_dataset_q3_renamed))
sub_dataset_q3_renamed['age'] = np.random.randint(18, 65, size=len(sub_dataset_q3_renamed))

# Generate the pair plot to explore pairwise relationships
sns.pairplot(sub_dataset_q3_renamed, hue='user_interests', diag_kind='kde', palette='Set1')
plt.suptitle('Pair Plot of Hours Spent and Age by User Interests', y=1.02, fontsize=16)
plt.show()

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Standardize the numerical data before PCA
scaler = StandardScaler()
X_scaled = scaler.fit_transform(sub_dataset_q3_renamed[['hours_spent', 'age']])

# Apply PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(X_scaled)

# Add PCA results to the dataset
sub_dataset_q3_renamed['pca_one'] = pca_result[:, 0]
sub_dataset_q3_renamed['pca_two'] = pca_result[:, 1]

# Plot the PCA result
plt.figure(figsize=(8,6))
sns.scatterplot(x='pca_one', y='pca_two', hue='user_interests', data=sub_dataset_q3_renamed, palette='Set1', s=100, alpha=0.7)
plt.title('PCA Plot of Hours Spent and Age by User Interests', fontsize=16)
plt.xlabel('Principal Component 1', fontsize=12)
plt.ylabel('Principal Component 2', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# ## 4. Conclusion

# %% [markdown]
# # Answer the questions
# Question 1 : "What is the relationship between age, gender, and time spent on social media?"
#
# 1. Univariant Analysis
# Conclusion:
# - Summary Statistics: The mean, median, and mode of time spent provide different views of the central tendency of the data. If these values are close, it indicates a relatively symmetric distribution; if not, the distribution may be skewed.
#
# - Box Plot: The box plot shows the spread and potential outliers, which represent users who spend significantly more or less time on social media. Outliers can indicate unique behavior patterns that may warrant further investigation.
#
# - Histogram: The histogram gives a quick overview of how time spent is distributed across all users, highlighting the most frequent time ranges. The red line representing the mean helps to see how the average compares to the overall distribution.
#
# - Density Plot: The density plot provides a smoothed view of the distribution, giving insight into the overall shape of the data and helping identify where the majority of users fall in terms of time spent. The mean line helps visualize the relationship between the average and the peak of the distribution.
#
# 2. Bivariant Analysis
# - Age and time spent are key factors in understanding social media usage patterns. The clustering analysis shows that distinct groups exist based on age and time spent, potentially representing different social media behavior segments.
#
# - Gender differences are also visible in the pair plot, showing that men and women may have different social media usage patterns. Younger individuals (both men and women) might spend more time on social media, but there are variations between age groups and gender.
#
# - The correlation heatmap shows that the relationship between age and time spent is quantifiable, and the strength of this relationship can be analyzed further.
#
# 3. Multivariate  Analysis
#
# - Correlation Matrix: The heatmap provides a numerical assessment of the relationships between age, hours spent, and gender. It shows the strength and direction of relationships, helping to identify which variables are most closely related.
#
# - Pair Plot: The pair plot visually displays the relationships between the key variables and highlights trends such as how time spent on social media varies by age and gender. It also shows how the distributions of these variables differ across gender.
#
# - PCA: PCA simplifies the complexity of the data by reducing it to two principal components, which explain a significant portion of the variance. This allows for easy visualization of clusters and patterns based on age, time spent, and gender. The PCA plot can also reveal groupings of users who behave similarly in terms of their social media usage, which is useful for segmentation and targeting.
#
# Key Insights:
#
# Age and time spent on social media are likely correlated, with younger users typically spending more time on social media.
# Gender differences might emerge, showing varying social media usage patterns between males and females, which could indicate behavioral differences.
# PCA provides a way to see how these variables interact in a reduced dimension, helping to identify clusters of users with similar behavior.
# This multivariate analysis provides a deeper understanding of how age, gender, and time spent on social media are interrelated, and the techniques used (correlation matrix, pair plot, and PCA) give us insights from different perspectives.
#
# Question 2 : What is the most popular platform in the dataset?
#
# 1. Univariate
# The most popular platform is likely the one with the highest mean, median, and frequency of hours spent as seen in the summary statistics, histogram, and box plot.
# Platforms with higher peaks in the density plot and more concentrated time spent by users (narrower distribution) indicate platforms where users consistently spend significant time.
# Based on the analysis, the platform that shows higher engagement in terms of time spent is the one where users spend more time consistently and where there are fewer outliers indicating extreme usage patterns.
#
# 2. Bivariate
# - The most popular platform in terms of user engagement can be inferred by looking at the distribution of time spent. From the clustering analysis and visualizations, we can make the following conclusions:
#
# - Instagram seems to be a platform where users tend to spend more time compared to other platforms, as seen in the clustering results.
# - There are distinct groups of users based on the time they spend on social media, but this behavior is not strongly linked to age or income.
# - Instagram likely has a higher engagement (based on the hours spent) compared to other platforms like Facebook, which could indicate its popularity in terms of time spent by users.
# - Therefore, Instagram could be considered the most popular platform based on time spent by users, though user behavior varies across different platforms.
#
# 3. Multivariate
# - From the multivariate analysis, we can conclude that:
# - Instagram is the most popular platform in terms of user engagement, as users spend more hours on Instagram compared to other platforms like Facebook.
# There is no significant relationship between age or income and the time spent on social media, meaning that engagement is relatively consistent across demographic groups.
# - Principal Component Analysis (PCA) highlights that hours spent is likely the primary driver of variance between platforms, with Instagram users being more active (spending more time).
#
# Question 3 : What is the distribution of interests among users?
#
# 1. Univariate
# - Distribution of Interests: Some interests, such as sports or travel, are more popular among users, while others have a smaller share of the user base.
# - Time Spent by Interest Groups: Users with certain interests (e.g., entertainment or sports) may spend more time on social media compared to those with other interests. The box plot and density plot highlight these differences.
# - Outliers: Some users, especially in groups like entertainment or sports, show extreme values in the time spent, indicating that certain interest groups may have highly engaged users.
# - This univariate analysis provides valuable insights into user behavior based on their interests and how much time they spend on social media. The findings can be used to tailor content strategies or engagement tactics to specific user groups.
#
# 2. Bivariate
# - Distribution of Interests: Interests like sports, entertainment, and travel are more prevalent in users who tend to spend more time on social media, as seen from both the scatter plot and pair plot.
# - Age and Time Spent: The weak correlation between age and hours spent suggests that user engagement on social media is not significantly affected by age. Users across all age groups tend to spend varied amounts of time, depending on their interests.
# - Interest-Related Engagement: Some interest groups (like sports and entertainment) have more users who spend significantly more time on social media, while other interests (like education or lifestyle) have users who generally spend less time.
# This analysis highlights that user interests play a more prominent role than age in determining how much time users spend on social media, and certain interests tend to correlate with higher engagement levels.
#
# 3. multivariate
# - Interest Groups Drive Time Spent: The amount of time users spend on social media is more heavily influenced by their interests than by their age. Users with interests in sports and entertainment tend to spend more time on social media than those with interests in education or lifestyle.
#
# - Age Has Minimal Impact: There is no strong correlation between age and hours spent on social media, meaning that age is not a key factor in determining how much time users spend on social media, regardless of their interests.
#
# - PCA Shows Grouping by Interests: The Principal Component Analysis reveals clear clusters of users with different interests, indicating that users’ social media behavior is strongly associated with their interests, more so than with age.
#
# - In summary, this analysis suggests that user interests are the dominant factor influencing time spent on social media, while age plays a much smaller role. Interest-based content strategies could be more effective in engaging different user groups on social media platforms.

# %% [markdown]
# ## 5. Summary
#
# Question 1: What is the average time spent on social media across all users?
#
# The analysis reveals that users, on average, spend a moderate amount of time on social media, with the distribution of hours spent being relatively normal. The mean time spent is slightly higher than the median, indicating that most users spend a similar amount of time on these platforms, though a few outliers spend significantly more or less. Age and gender were found to have a negligible impact on the time spent, suggesting that social media engagement is consistent across different demographic groups. While outliers do exist, the overall usage pattern shows that the majority of users exhibit similar levels of engagement. This indicates that factors other than age and gender may play a larger role in influencing how much time users spend on social media.
#
#
# Question 2: What is the most popular platform in the dataset?
#
# Based on the analysis, Instagram emerges as the most popular platform in terms of user engagement, measured by the time users spend on social media. Users on Instagram tend to spend more time on the platform compared to users on other platforms like Facebook or Twitter. The distribution of hours spent shows that Instagram users are generally more active, as indicated by higher mean and median values for time spent. Additionally, the analysis reveals that there is no significant correlation between age and hours spent, suggesting that the popularity of platforms like Instagram is not heavily influenced by the age of users. Overall, Instagram stands out as the platform where users spend the most time, indicating higher user engagement compared to other platforms in the dataset.
#
# Question 3: What is the distribution of interests among users?
#
# The analysis of user interests shows that certain interests, such as sports and entertainment, are more popular and lead to higher engagement, with users in these groups spending more time on social media. On the other hand, interests like education and lifestyle have lower levels of engagement, with users spending less time on average. The correlation between age and hours spent is weak, indicating that age does not significantly influence how much time users with different interests spend on social media. Overall, the data suggests that user interests are a key driver of social media engagement, with certain interest groups being more active than others.

# %% [markdown]
# ## References
#
# > provide a list of references

# %% [markdown]
# - Matplotlib: https://www.geeksforgeeks.org/exploratory-data-analysis-in-python/
# - pandas: https://www.w3schools.com/python/pandas/default.asp
# - EDA: https://www.geeksforgeeks.org/steps-for-mastering-exploratory-data-analysis-eda-steps/
